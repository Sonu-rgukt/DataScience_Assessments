# %%
import folium
# define the world map
world_map = folium.Map()

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
#resize our map by using the branca library in Python
from branca.element import Figure
fig=Figure(width=550,height=350)
map1=folium.Map(location=[16.7850, 80.8488],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
path1=[[16.79299134730435, 80.82070064173806],[16.78612061834646, 80.84826305481401],[16.802658712148176, 80.83728695980243],[16.677692113989544, 80.95113470624688],[16.711203684551677, 81.02709730219105],[16.742827262728433, 81.0820096514907],[16.830397839594198, 81.24994637879735],[17.01105067290339, 81.52050661014327],[17.0290840246808, 81.71981562554325],[17.177383197036058, 82.06014112617194],[17.271954185761146, 82.4051814633107],[17.36892861679549, 82.5416060626712],[17.43337871998449, 82.74374547327147],[17.566110338653747, 82.86187135504476],[17.690831176452388, 83.00075921789694],[17.78706422781361, 83.11921107970696],[17.93398715602714, 83.42282131185983],[18.03258387206646, 83.49685916617305],[18.145298044795528, 83.6207749872705],[18.278428067603773, 83.83057729599983],[18.33423779504099, 83.88831191216093],[18.318663207234536, 83.92735992852457],[18.377839176152982, 83.99626820288066],[18.420290146615837, 84.03946730600369],[18.42055702562896, 84.04002988881676],[18.52220775651939, 84.14945225479704],[18.612063174257887, 84.2254392940294],[18.7161792924391, 84.34842866139522],[18.748960115683925, 84.40000768640421],[18.782681789711773, 84.40825747091476],[18.889708086628563, 84.54045520734431],[18.92061017628507, 84.55923002523565],[18.919402423777406, 84.54712789834095]]
path2=[[16.78755963080697, 80.85004802696056],[16.78683811963395, 80.85326362882556],[16.777963218973746, 80.8796994791845],[16.7914397567335, 80.89995552036861],[16.7914397567335, 80.89858222944088],[16.78782419411337, 80.91643501150145],[16.77401868562408, 80.9720532940748],[16.76185585923777, 80.99024939886733],[16.752979792372223, 81.0211484447414],[16.74081562107487, 81.05033087695581],[16.74147316371311, 81.05067419968773],[16.735226417013738, 81.06578039989286]]

# %%
fig5=Figure(height=550,width=750)
map6=folium.Map(location=[16.78612061834646, 80.84826305481401],tiles='cartodbpositron',zoom_start=14)
fig5.add_child(map6)

# %%
# Creating feature groups
f1=folium.FeatureGroup("Path")


# Adding lines to the different feature groups
line_0= folium.vector_layers.PolyLine(path1,popup='<b>Path to home</b>',tooltip='Home Way',color='red',weight=10).add_to(f1)
line_1= folium.vector_layers.PolyLine(path2,popup='<b>Path to home</b>',tooltip='Home Way',color='blue',weight=10).add_to(f1)
folium.Marker(location=[16.722584298154693, 81.04885536777044],popup='Eluru College Of Engineering ఏలూరు కాలేజ్ ఆఫ్ ఇంజినీరింగ్',tooltip='Click here to see more details',icon=folium.Icon(color='purple',prefix='fa',icon=' fa-institution')).add_to(map6)
folium.Marker(location=[18.92027176010295, 84.54654537573255],popup='Home',tooltip='Click here to see more details',icon=folium.Icon(color='red',icon='home')).add_to(map6)
folium.Marker(location=[17.039815114206736, 81.78938832361798],popup='DMART',tooltip='Click here to see more details',icon=folium.Icon(color='blue',prefix='fa',icon='fa-cart-plus')).add_to(map6)
folium.Marker(location=[16.71752248221699, 81.03531594026133],popup='Bharat Petroleum, Petrol Pump -Parvathi Energy Station భారత్ పెట్రోలియం, పెట్రోల్ పంప్ -పార్వతి ఎనర్జీ స్టేషన్',tooltip='Click here to see more details',icon=folium.Icon(color='blue',prefix='fa',icon='fa-tint')).add_to(map6)
folium.Marker(location=[16.666191706443186, 81.00951541808914],popup='Sankranti family Restaurant A/C సంక్రాంతి ఫ్యామిలీ రెస్టారెంట్ A / C',tooltip='Click here to see more details',icon=folium.Icon(color='orange',prefix='fa',icon='fa-cutlery')).add_to(map6)
folium.Marker(location=[17.23479724101986, 82.18564046877927],popup='Government Hospital గవర్నమెంట్ హాస్పిటల్',tooltip='Click here to see more details',icon=folium.Icon(color='red',prefix='fa',icon='fa-heartbeat')).add_to(map6)
folium.Marker(location=[17.22191785652608, 82.27262809698996],popup='Vannepudi junction temple వన్నెపూడి జంక్షన్ ఆలయం',tooltip='Click here to see more details',icon=folium.Icon(color='orange',prefix='fas',icon='fa-gopuram')).add_to(map6)
folium.Marker(location=[18.269427944119396, 83.81251621558243],popup='RGUKT IIIT Boys Campus, Srikakulam RGUKT IIIT బాయ్స్ క్యాంపస్, శ్రీకాకుళం',tooltip='Click here to see more details',icon=folium.Icon(color='grey',prefix='fa',icon='fa-graduation-cap')).add_to(map6)
folium.Marker(location=[16.797135093666196, 80.81980253778333],popup='IIIT Nuzvid Campus నూజివీడు ఐ ఐ ఐ టి Nuzividu, Andhra Pradesh 521202',tooltip='Click here to see more details',icon=folium.Icon(color='blue',prefix='fa',icon='fa-graduation-cap')).add_to(map6)


f1.add_to(map6)
folium.LayerControl().add_to(map6)
map6
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:15: UserWarning: color argument of Icon should be one of: {'lightblue', 'orange', 'green', 'lightgray', 'blue', 'darkblue', 'black', 'lightgreen', 'lightred', 'darkred', 'darkgreen', 'red', 'beige', 'darkpurple', 'gray', 'purple', 'white', 'pink', 'cadetblue'}.
#   from ipykernel import kernelapp as app
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...
