# %%
import pandas as pd
data=pd.read_csv("100000 Sales Records.csv")

# %%
data
# Out:
#                                   Region                Country  \
# 0           Middle East and North Africa             Azerbaijan
# 1      Central America and the Caribbean                 Panama
# 2                     Sub-Saharan Africa  Sao Tome and Principe
# 3                     Sub-Saharan Africa  Sao Tome and Principe
# 4      Central America and the Caribbean                 Belize
# ...                                  ...                    ...
# 99995                 Sub-Saharan Africa                  Niger
# 99996                             Europe                 Poland
# 99997                 Sub-Saharan Africa                Comoros
# 99998       Middle East and North Africa                 Kuwait
# 99999                 Sub-Saharan Africa               Tanzania
#
#            Item Type Sales Channel Order Priority Order Date   Order ID  \
# 0             Snacks        Online              C  10/8/2014  535113847
# ...

# %%
data.size
# Out:
# 1400000

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (100000, 14)

# %%
data.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          100000 non-null  object
#  1   Country         100000 non-null  object
#  2   Item Type       100000 non-null  object
#  3   Sales Channel   100000 non-null  object
#  4   Order Priority  100000 non-null  object
#  5   Order Date      100000 non-null  object
#  6   Order ID        100000 non-null  int64
#  7   Ship Date       100000 non-null  object
#  8   Units Sold      100000 non-null  int64
#  9   Unit Price      100000 non-null  float64
#  10  Unit Cost       100000 non-null  float64
#  11  Total Revenue   100000 non-null  float64
#  12  Total Cost      100000 non-null  float64
#  13  Total Profit    100000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 10.7+ MB

# %%
data.describe()
# Out:
#            Order ID     Units Sold     Unit Price      Unit Cost  \
# count  1.000000e+05  100000.000000  100000.000000  100000.000000
# mean   5.503956e+08    5001.446170     266.703989     188.019711
# std    2.593219e+08    2884.575424     216.940081     175.706023
# min    1.000089e+08       1.000000       9.330000       6.920000
# 25%    3.260464e+08    2505.000000     109.280000      56.670000
# 50%    5.477185e+08    5007.000000     205.700000     117.110000
# 75%    7.750785e+08    7495.250000     437.200000     364.690000
# max    9.999965e+08   10000.000000     668.270000     524.960000
#
#        Total Revenue    Total Cost  Total Profit
# count   1.000000e+05  1.000000e+05  1.000000e+05
# mean    1.336067e+06  9.419755e+05  3.940912e+05
# std     1.471768e+06  1.151828e+06  3.795986e+05
# min     1.866000e+01  1.384000e+01  4.820000e+00
# 25%     2.797533e+05  1.629283e+05  9.590000e+04
# 50%     7.898916e+05  4.679374e+05  2.836575e+05
# ...

# %%
data["Region"]
# Out:
# 0             Middle East and North Africa
# 1        Central America and the Caribbean
# 2                       Sub-Saharan Africa
# 3                       Sub-Saharan Africa
# 4        Central America and the Caribbean
#                        ...
# 99995                   Sub-Saharan Africa
# 99996                               Europe
# 99997                   Sub-Saharan Africa
# 99998         Middle East and North Africa
# 99999                   Sub-Saharan Africa
# Name: Region, Length: 100000, dtype: object

# %%
data["Region"].value_counts()
# Out:
# Sub-Saharan Africa                   26019
# Europe                               25877
# Asia                                 14547
# Middle East and North Africa         12580
# Central America and the Caribbean    10731
# Australia and Oceania                 8113
# North America                         2133
# Name: Region, dtype: int64

# %%
data["Units Sold"].value_counts()
# Out:
# 172     23
# 5955    22
# 1679    22
# 9358    21
# 4807    21
#         ..
# 6300     2
# 2136     1
# 4951     1
# 6828     1
# 2523     1
# Name: Units Sold, Length: 9998, dtype: int64

# %%
print(data["Units Sold"].max())
print(data["Units Sold"].min())
print(data["Units Sold"].mean())
print(data["Units Sold"].std())
# Out:
# 10000
# 1
# 5001.44617
# 2884.575424393705

# %%
data[data["Units Sold"]>=7000]
# Out:
#                                   Region                 Country  \
# 2                     Sub-Saharan Africa   Sao Tome and Principe
# 3                     Sub-Saharan Africa   Sao Tome and Principe
# 6                                 Europe                 Germany
# 8                                 Europe          United Kingdom
# 15     Central America and the Caribbean  Saint Kitts and Nevis
# ...                                  ...                     ...
# 99984                               Asia             North Korea
# 99989                             Europe                Slovenia
# 99990                 Sub-Saharan Africa            Sierra Leone
# 99997                 Sub-Saharan Africa                 Comoros
# 99998       Middle East and North Africa                  Kuwait
#
#              Item Type Sales Channel Order Priority  Order Date   Order ID  \
# 2               Fruits       Offline              M   12/9/2015  854349935
# ...

# %%
data[(data["Units Sold"]<=7000) & (data["Sales Channel"]=="Offline")]
# Out:
#                                   Region   Country   Item Type Sales Channel  \
# 1      Central America and the Caribbean    Panama   Cosmetics       Offline
# 4      Central America and the Caribbean    Belize   Household       Offline
# 12                                Europe     Malta   Household       Offline
# 13          Middle East and North Africa    Jordan   Household       Offline
# 14                                  Asia  Cambodia  Vegetables       Offline
# ...                                  ...       ...         ...           ...
# 99993                               Asia  Maldives      Snacks       Offline
# 99994                               Asia   Vietnam   Baby Food       Offline
# 99995                 Sub-Saharan Africa     Niger      Cereal       Offline
# 99996                             Europe    Poland        Meat       Offline
# 99999                 Sub-Saharan Africa  Tanzania   Cosmetics       Offline
#
# ...

# %%
data.iloc[1,3]
# Out:
# 'Offline'

# %%
data.iloc[-1,-1]
# Out:
# 561426.23

# %%
data["Sales Channel"].describe(include="o")
# Out:
# count     100000
# unique         2
# top       Online
# freq       50054
# Name: Sales Channel, dtype: object

# %%
data["Sales Channel"].unique()
# Out:
# array(['Online', 'Offline'], dtype=object)

# %%
data.memory_usage()
# Out:
# Index                128
# Region            800000
# Country           800000
# Item Type         800000
# Sales Channel     800000
# Order Priority    800000
# Order Date        800000
# Order ID          800000
# Ship Date         800000
# Units Sold        800000
# Unit Price        800000
# Unit Cost         800000
# Total Revenue     800000
# Total Cost        800000
# Total Profit      800000
# dtype: int64

# %%
data.head(100)
# Out:
#                                Region                Country      Item Type  \
# 0        Middle East and North Africa             Azerbaijan         Snacks
# 1   Central America and the Caribbean                 Panama      Cosmetics
# 2                  Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                  Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4   Central America and the Caribbean                 Belize      Household
# ..                                ...                    ...            ...
# 95                      North America                 Mexico  Personal Care
# 96       Middle East and North Africa                Lebanon      Baby Food
# 97                               Asia            South Korea      Beverages
# 98       Middle East and North Africa   United Arab Emirates           Meat
# 99                             Europe                Georgia      Household
#
# ...

# %%
data.tail(200)
# Out:
#                              Region     Country        Item Type  \
# 99800                        Europe      Russia  Office Supplies
# 99801            Sub-Saharan Africa     Namibia           Cereal
# 99802  Middle East and North Africa        Iran           Cereal
# 99803         Australia and Oceania  East Timor       Vegetables
# 99804                        Europe       Italy           Fruits
# ...                             ...         ...              ...
# 99995            Sub-Saharan Africa       Niger           Cereal
# 99996                        Europe      Poland             Meat
# 99997            Sub-Saharan Africa     Comoros          Clothes
# 99998  Middle East and North Africa      Kuwait        Cosmetics
# 99999            Sub-Saharan Africa    Tanzania        Cosmetics
#
#       Sales Channel Order Priority Order Date   Order ID   Ship Date  \
# 99800        Online              L   2/6/2013  704725587   2/14/2013
# ...

# %%
data.at[1,"Country"]
# Out:
# 'Panama'

# %%
data.loc[1:12,"Item Type"]
# Out:
# 1         Cosmetics
# 2            Fruits
# 3     Personal Care
# 4         Household
# 5           Clothes
# 6         Cosmetics
# 7            Fruits
# 8            Snacks
# 9         Cosmetics
# 10        Cosmetics
# 11          Clothes
# 12        Household
# Name: Item Type, dtype: object

# %%
data.loc[1:12,"Country"]
# Out:
# 1                    Panama
# 2     Sao Tome and Principe
# 3     Sao Tome and Principe
# 4                    Belize
# 5                   Denmark
# 6                   Germany
# 7                    Turkey
# 8            United Kingdom
# 9                Kazakhstan
# 10                    Haiti
# 11                    Italy
# 12                    Malta
# Name: Country, dtype: object

# %%
data.iat[343,2]
# Out:
# 'Office Supplies'

# %%
data.iat[345,2:7]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-ed854508d070> in <module>
# ----> 1 data.iat[345,2:7]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2024                 raise ValueError("Invalid call for scalar access (getting)!")
#    2025
# -> 2026         key = self._convert_key(key)
#    2027         return self.obj._get_value(*key, takeable=self._takeable)
#    2028
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2102         for a, i in zip(self.obj.axes, key):
#    2103             if not is_integer(i):
# -> 2104                 raise ValueError("iAt based indexing can only have integer indexers")
#    2105         return key
#    2106
#
# ValueError: iAt based indexing can only have integer indexers

# %%
data.iloc[345,2:7]
# Out:
# Item Type         Household
# Sales Channel        Online
# Order Priority            M
# Order Date         2/8/2011
# Order ID          595473849
# Name: 345, dtype: object

# %%
data.dtypes
# Out:
# Region             object
# Country            object
# Item Type          object
# Sales Channel      object
# Order Priority     object
# Order Date         object
# Order ID            int64
# Ship Date          object
# Units Sold          int64
# Unit Price        float64
# Unit Cost         float64
# Total Revenue     float64
# Total Cost        float64
# Total Profit      float64
# dtype: object

# %%
data.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-087aa1c5d757> in <module>
# ----> 1 data.get_dtype_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
data["Item Type"].unique()
# Out:
# array(['Snacks', 'Cosmetics', 'Fruits', 'Personal Care', 'Household',
#        'Clothes', 'Vegetables', 'Office Supplies', 'Beverages', 'Meat',
#        'Cereal', 'Baby Food'], dtype=object)

# %%
data["Total Revenue"].nbytes
# Out:
# 800000

# %%
data["favourite_item"]="snacks"

# %%
data.head()
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
# 3        Online              M  9/17/2014  892836844  10/12/2014        9118
# 4       Offline              H   2/4/2010  129280602    3/5/2010        5858
#
# ...

# %%
data["favourite_city"].replace("ahmedabad","nagpur",inplace=True)

# %%
data["favourite_item"].replace("snacks","cosmotics",inplace=True)

# %%
data.head()
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
# 3        Online              M  9/17/2014  892836844  10/12/2014        9118
# 4       Offline              H   2/4/2010  129280602    3/5/2010        5858
#
# ...

# %%
data["Order ID"]=data["Order ID"].astype("str")

# %%
data.head()
# Out:
#                               Region                Country      Item Type  \
# 0       Middle East and North Africa             Azerbaijan         Snacks
# 1  Central America and the Caribbean                 Panama      Cosmetics
# 2                 Sub-Saharan Africa  Sao Tome and Principe         Fruits
# 3                 Sub-Saharan Africa  Sao Tome and Principe  Personal Care
# 4  Central America and the Caribbean                 Belize      Household
#
#   Sales Channel Order Priority Order Date   Order ID   Ship Date  Units Sold  \
# 0        Online              C  10/8/2014  535113847  10/23/2014         934
# 1       Offline              L  2/22/2015  874708545   2/27/2015        4551
# 2       Offline              M  12/9/2015  854349935   1/18/2016        9986
# 3        Online              M  9/17/2014  892836844  10/12/2014        9118
# 4       Offline              H   2/4/2010  129280602    3/5/2010        5858
#
# ...

# %%
type(data.loc[1,"Order ID"])
# Out:
# str

# %%
data.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# favourite_city    0
# favourite_item    0
# dtype: int64

# %%
data["Total Revenue"].sum()
# Out:
# 133606673066.41002

# %%
data["Total Revenue"].describe()
# Out:
# count    1.000000e+05
# mean     1.336067e+06
# std      1.471768e+06
# min      1.866000e+01
# 25%      2.797533e+05
# 50%      7.898916e+05
# 75%      1.836490e+06
# max      6.682700e+06
# Name: Total Revenue, dtype: float64

# %%
data["Total Revenue"].mean()
# Out:
# 1336066.7306640968

# %%
data["Total Revenue"].count()
# Out:
# 100000

# %%
data[data["Total Revenue"]==data["Total Revenue"].max()]
# Out:
#                    Region     Country  Item Type Sales Channel Order Priority  \
# 87235  Sub-Saharan Africa  Cape Verde  Household        Online              M
#
#       Order Date   Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  \
# 87235  5/14/2011  257909476  6/19/2011       10000      668.27     502.54
#
#        Total Revenue  Total Cost  Total Profit
# 87235      6682700.0   5025400.0     1657300.0
